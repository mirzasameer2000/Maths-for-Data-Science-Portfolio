# %% [markdown]
# # Maths for Data Science Portfolio
# ## Muhammad Sameer
# ### 24169956
# ### Arden University Berlin

# %% [markdown]
# ##### Core Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy import stats

# %% [markdown]
# ### Gaussian Elimination
# #### Linear Algebra – Heat flow on the steel plate
# * solving linear system using np.linalg.solve()

# %%
A = np.array([
    [4, -1, -1, 0],
    [-1, 4, 0, -1],
    [-1, 0, 4, -1],
    [0, -1, -1, 4]
], dtype=float)

b = np.array([100, 100, 0, 0], dtype=float)

x = np.linalg.solve(A, b)
print(x)
# Out:
# [37.5 37.5 12.5 12.5]

# %% [markdown]
# ### Calculus – Where does temperature change fastest?

# %%
x = np.linspace(0, 10, 400)
T = 100 * np.sin(np.pi * x / 10)
Tp = 10 * np.pi * np.cos(np.pi * x / 10)

plt.plot(x, T)
plt.xlabel('Position x')
plt.ylabel('Temperature T(x)')
plt.title('Temperature along plate edge')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Probability – Error greater than 3°C

# %%
p_one = norm.sf(3, loc=0, scale=2)   # P(E > 3)
p_two = 2 * p_one                    # P(|E| > 3)

print("One-sided:", p_one)
print("Two-sided:", p_two)
# Out:
# One-sided: 0.06680720126885807
# Two-sided: 0.13361440253771614

# %% [markdown]
# ### Hypothesis Test – Is mean temperature 100°C?

# %%
data = np.array([99, 100, 98, 101, 97, 99, 100, 98])
t_stat, p_value = stats.ttest_1samp(data, 100)

print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: -2.160246899469287
# p-value: 0.06758329382336989

# %% [markdown]
# #### Since 𝑝 ≈ 0.068 > 0.05, we fail to reject 𝐻0.
